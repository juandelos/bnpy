# %%
# %matplotlib inline

# %% [markdown]
# # Variational with birth and merge proposals for DP mixtures of Gaussians
#
# How to train a DP mixture model.
#
# We'll show that despite diverse, poor quality initializations, our proposal moves that insert new clusters (birth) and remove redundant clusters (merge) can consistently recover the same ideal posterior with 8 clusters.

# %% [markdown]
# Read dataset from file.

# %%
import bnpy
import numpy as np
import os
import torch
from bnpy.data.XData import XData
# from sklearn.manifold import TSNE
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
import scipy.io as scio
from torchvision.datasets import MNIST, CIFAR10, FashionMNIST, SVHN, KMNIST, STL10
from scipy.optimize import linear_sum_assignment

# from matplotlib import pylab
# import seaborn as sns

# %%
seed = 1
np.random.seed(seed)
# n_components = 3
num_digits = 10
dataset_type = 'mnist'
dataset_path = 'dataset/mnist/'
# dataset_type = 'fashion-mnist'
# dataset_path = 'dataset/fashion/'
# dataset_type = 'reuters10k'
# dataset_path = 'dataset/reuters10k/'
# dataset_type = 'har'
# dataset_path = 'dataset/har/'


# Define the transforms to apply to the data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

class Reuters10kDataset(Dataset):
    '''Reuters 10k dataset torchvision wrapper
        Args:
            data_path: path/to/save/the/reuters10k.mat (filename not included)
            train: if True split 80% of total dataset as train dataset otherwise 20% as test set
        Outputs:
            data: shape (batch_size, 2000) text tokens
            labels: shape (batch_size, 1) indicators of text categories
    '''
    def __init__(self, data_path, train=True):
        # load data and labels from data_path
        self.content=scio.loadmat(data_path+'reuters10k.mat')
        length = len(self.content['X'])
        train_limits = int(0.8*length)
        self.labels = self.content['Y'].squeeze()

        if train is True: # split train/test == 8/2
            self.data = self.content['X'][:train_limits]
            self.labels = self.labels[:train_limits]
        else:
            self.data = self.content['X'][train_limits:]
            self.labels = self.labels[train_limits:]

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # get data and label at idx
        x = self.data[idx]
        y = self.labels[idx]
        # convert data to tensor and normalize
        x = torch.tensor(x, dtype=torch.float32)
        # return data and label as tuple
        return x, y

class HARDataset(Dataset):
    '''HAR dataset torchvision wrapper
        Args:
            data_path: path/to/save/the/HAR.mat(filename not included), data from VaDE
            train: if True split 80% of total dataset as train dataset otherwise 20% as test set
        Outputs:
            data: shape (batch_size, 561) sensor
            labels: shape (batch_size, 1) indicators of action categories
    '''
    def __init__(self, data_path, train=True):
        # load data and labels from data_path
        self.content=scio.loadmat(data_path+'HAR.mat')
        self.labels = self.content['Y'] -1
        self.labels = self.labels.squeeze()
        self.data = self.content['X']
        # print(self.labels.shape)
        
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        # get data and label at idx
        x = self.data[idx]
        y = self.labels[idx]
        # convert data to tensor and normalize
        x = torch.tensor(x, dtype=torch.float32)
        # return data and label as tuple
        return x, y


def configure_subset(dataset:Dataset, num_digits:int):
    '''
    limit the representations (type of digits) in the dataset, to build a subset 
    e.g. num_digits = 3, the subset should only contents digits [0,1,2]
    '''
    if num_digits < 4:
        digits = list(np.arange(num_digits))
        select_idxs = [i for i in range(len(dataset)) if dataset.labels[i] in digits]
        subset = Subset(dataset, select_idxs)
    else:
        subset = dataset
    return subset

def train_dataset():

    if dataset_type == 'mnist':
        full_train_dataset = MNIST(root = dataset_path,
                                    train = True, 
                                    transform=transform, 
                                    download=True)
    elif dataset_type == 'fashion-mnist':
        full_train_dataset = FashionMNIST(root = dataset_path,
                            train = True, 
                            transform = transform, 
                            download = True,
                            )
    elif dataset_type == 'reuters10k':
        full_train_dataset = Reuters10kDataset(data_path=dataset_path, train=True)
    else:
        full_train_dataset = HARDataset(data_path=dataset_path)

    
    dataset = configure_subset(full_train_dataset, num_digits)
    labels = np.array([y for x, y in dataset])

    if dataset_type != 'reuters10k':
        data = np.array([np.array(x.flatten()) for x, y in dataset])
    else:
        data = np.array([np.array(x) for x, y in dataset])
    
    return data, labels

def test_dataset():
    if dataset_type == 'mnist':
        full_test_dataset = MNIST(root = dataset_path,
                                  train = False,
                                  transform=transform, 
                                  download=True)
    elif dataset_type == 'fashion-mnist':
        full_test_dataset = FashionMNIST(root = dataset_path,
                            train = True, 
                            transform = transform, 
                            download = True,
                            )
    elif dataset_type == 'reuters10k':
        full_test_dataset = Reuters10kDataset(data_path=dataset_path, train=False)
    else:
        full_test_dataset = HARDataset(data_path=dataset_path)
    
    dataset = configure_subset(full_test_dataset, num_digits)
    if dataset_type != 'reuters10k':
        data = np.array([np.array(x.flatten()) for x, y in dataset])
    else:
        data = np.array([np.array(x) for x, y in dataset])
    labels = np.array([y for x, y in dataset])
    return data, labels

def unsupervised_clustering_accuracy(y: np.ndarray, y_pred: np.ndarray) -> tuple:
    """Unsupervised Clustering Accuracy
    """
    assert len(y_pred) == len(y)
    u = np.unique(y)
    n_true_clusters = len(u)
    v = np.unique(y_pred)
    n_pred_clusters = len(v)
    map_u = dict(zip(u, range(n_true_clusters)))
    map_v = dict(zip(v, range(n_pred_clusters)))
    # inv_map_u = {v: k for k, v in map_u.items()}
    # inv_map_v = {v: k for k, v in map_v.items()}
    r = np.zeros((n_pred_clusters, n_true_clusters), dtype=np.int64)
    for y_pred_, y_ in zip(y_pred, y):
        if y_ in map_u:
            r[map_v[y_pred_], map_u[y_]] += 1
    reward_matrix  = np.concatenate((r, r, r), axis=1)
    cost_matrix = reward_matrix.max() - reward_matrix
    row_assign, col_assign = linear_sum_assignment(cost_matrix)

    # Construct optimal assignments matrix
    row_assign = row_assign.reshape((-1, 1))  # (n,) to (n, 1) reshape
    col_assign = col_assign.reshape((-1, 1))  # (n,) to (n, 1) reshape
    # assignments = np.concatenate((row_assign, col_assign), axis=1)
    # assignments = [[inv_map_v[x], inv_map_u[y%n_true_clusters]] for x, y in assignments]

    optimal_reward = reward_matrix[row_assign, col_assign].sum() * 1.0
    return optimal_reward / y_pred.size

train_data, train_label = train_dataset()
test_data, test_label = test_dataset()
print(train_data.shape, train_label.shape)
print(test_data.shape, test_label.shape)
# Out:
# (60000, 784) (60000,)
# (10000, 784) (10000,)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 100, random_state = 1)

reduced_train_data = pca.fit_transform(train_data)
reduced_test_data = pca.fit_transform(test_data)
print(reduced_train_data.shape)
print(reduced_test_data.shape)
# Out:
# (60000, 100)
# (10000, 100)

# %%
import os
save_dir = "dpmm_save/"

train_data_for_dpmm = XData(reduced_train_data)
test_data_for_dpmm = XData(reduced_test_data)

model, info_dict = bnpy.run(train_data_for_dpmm, 'DPMixtureModel', 'DiagGauss', 'memoVB',
                            output_path=save_dir,
                            initname='randexamples',
                            K=4, gamma0=5.0,
                            ####################################################################
                            sF=0.1, ECovMat='eye', # sF=0.001 is able to classify all clusters
                            ####################################################################
                            moves='birth,merge,shuffle', nBatch=1, nLap=100,
                            b_startLap=1,

                            # birth kwargs
                            b_stopLap=100,
                            b_Kfresh=5,
                            # b_minNumAtomsForNewComp=16.0,
                            # b_minNumAtomsForTargetComp=16.0,
                            # b_minNumAtomsForRetainComp=16.0,
                            # b_minPercChangeInNumAtomsToReactivate=0.02,
                            # b_debugWriteHTML=0,
                            
                            # merge kwargs
                            m_startLap=2,
                            m_maxNumPairsContainingComp=50,
                            m_nLapToReactivate=1,
                            m_pair_ranking_procedure='obsmodel_elbo',
                            m_pair_ranking_direction='descending',
                            )
# Out:
# Dataset Summary:
# X Data
#   total size: 60000 units
#   batch size: 60000 units
#   num. batches: 1
# Allocation Model:  DP mixture with K=0. Concentration gamma0= 5.00
# Obs. Data  Model:  Gaussian with diagonal covariance.
# Obs. Data  Prior:  independent Gauss-Wishart prior on each dimension
#   Wishart params
#     nu = 102  ...
#   beta = [ 10  10]  ...
#   Expectations
#   E[  mean[k]] =
#   [ 0  0] ...
#   E[ covar[k]] =
#   [[0.1 0. ]
#    [0.  0.1]] ...
# Initialization:
#   initname = randexamples
#   K = 4 (number of clusters)
#   seed = 1607680
#   elapsed_time: 0.2 sec
# Learn Alg: memoVB | task  1/1 | alg. seed: 1607680 | data order seed: 8541952
# task_output_path: dpmm_save/1
# MERGE @ lap 1.00: Disabled. Cannot plan merge on first lap. Need valid SS that represent whole dataset.
# BIRTH @ lap 1.00 : Added 14 states. 4/4 succeeded. 0/4 failed eval phase. 0/4 failed build phase.
#     1.000/100 after      6 sec. |    957.9 MiB | K   18 | loss  1.814781628e+00 |
# BIRTH @ lap 2.000 : None attempted. 0 past failures. 0 too small. 18 too busy.
# MERGE @ lap 2.00 : 6/22 accepted. Ndiff 10806.00. 131 skipped.
#     2.000/100 after      7 sec. |    957.9 MiB | K   12 | loss  1.801885625e+00 |
# BIRTH @ lap 3.000 : None attempted. 0 past failures. 0 too small. 12 too busy.
# MERGE @ lap 3.00 : 1/47 accepted. Ndiff 6688.78. 19 skipped.
#     3.000/100 after      8 sec. |    957.9 MiB | K   11 | loss  1.798380431e+00 |
# BIRTH @ lap 4.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 4.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#     4.000/100 after      9 sec. |    957.9 MiB | K   11 | loss  1.796497557e+00 | Ndiff  414.071
# BIRTH @ lap 5.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 5.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#     5.000/100 after      9 sec. |    957.9 MiB | K   11 | loss  1.795445546e+00 | Ndiff  535.226
# BIRTH @ lap 6.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 6.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#     6.000/100 after     10 sec. |    957.9 MiB | K   11 | loss  1.794817388e+00 | Ndiff  555.913
# BIRTH @ lap 7.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 7.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#     7.000/100 after     11 sec. |    957.9 MiB | K   11 | loss  1.794381308e+00 | Ndiff  582.753
# BIRTH @ lap 8.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 8.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#     8.000/100 after     12 sec. |    957.9 MiB | K   11 | loss  1.794032561e+00 | Ndiff  595.232
# BIRTH @ lap 9.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 9.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#     9.000/100 after     12 sec. |    957.9 MiB | K   11 | loss  1.793715608e+00 | Ndiff  584.155
# BIRTH @ lap 10.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 10.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    10.000/100 after     13 sec. |    957.9 MiB | K   11 | loss  1.793404898e+00 | Ndiff  438.078
# BIRTH @ lap 11.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 11.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    11.000/100 after     14 sec. |    957.9 MiB | K   11 | loss  1.793212346e+00 | Ndiff  426.381
# BIRTH @ lap 12.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 12.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    12.000/100 after     14 sec. |    957.9 MiB | K   11 | loss  1.793093000e+00 | Ndiff  342.949
# BIRTH @ lap 13.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 13.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    13.000/100 after     15 sec. |    957.9 MiB | K   11 | loss  1.793005513e+00 | Ndiff  270.954
# BIRTH @ lap 14.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 14.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    14.000/100 after     16 sec. |    957.9 MiB | K   11 | loss  1.792936155e+00 | Ndiff  207.440
# BIRTH @ lap 15.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 15.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    15.000/100 after     17 sec. |    957.9 MiB | K   11 | loss  1.792876668e+00 | Ndiff  153.831
# BIRTH @ lap 16.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 16.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    16.000/100 after     18 sec. |    957.9 MiB | K   11 | loss  1.792822425e+00 | Ndiff  161.551
# BIRTH @ lap 17.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 17.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    17.000/100 after     18 sec. |    957.9 MiB | K   11 | loss  1.792770892e+00 | Ndiff  140.629
# BIRTH @ lap 18.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 18.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    18.000/100 after     19 sec. |    957.9 MiB | K   11 | loss  1.792710873e+00 | Ndiff  137.138
# BIRTH @ lap 19.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 19.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    19.000/100 after     20 sec. |    957.9 MiB | K   11 | loss  1.792622510e+00 | Ndiff  143.988
# BIRTH @ lap 20.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 20.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    20.000/100 after     21 sec. |    957.9 MiB | K   11 | loss  1.792576977e+00 | Ndiff  150.588
# BIRTH @ lap 21.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 21.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    21.000/100 after     22 sec. |    957.9 MiB | K   11 | loss  1.792557108e+00 | Ndiff  140.997
# BIRTH @ lap 22.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 22.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    22.000/100 after     22 sec. |    957.9 MiB | K   11 | loss  1.792539789e+00 | Ndiff  124.209
# BIRTH @ lap 23.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 23.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    23.000/100 after     23 sec. |    957.9 MiB | K   11 | loss  1.792521515e+00 | Ndiff  107.192
# BIRTH @ lap 24.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 24.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    24.000/100 after     24 sec. |    957.9 MiB | K   11 | loss  1.792500769e+00 | Ndiff  111.531
# BIRTH @ lap 25.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 25.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    25.000/100 after     24 sec. |    957.9 MiB | K   11 | loss  1.792476243e+00 | Ndiff  126.545
# BIRTH @ lap 26.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 26.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    26.000/100 after     25 sec. |    957.9 MiB | K   11 | loss  1.792445107e+00 | Ndiff  145.002
# BIRTH @ lap 27.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 27.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    27.000/100 after     26 sec. |    957.9 MiB | K   11 | loss  1.792401955e+00 | Ndiff  167.013
# BIRTH @ lap 28.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 28.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    28.000/100 after     27 sec. |    957.9 MiB | K   11 | loss  1.792336491e+00 | Ndiff  192.130
# BIRTH @ lap 29.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 29.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    29.000/100 after     27 sec. |    957.9 MiB | K   11 | loss  1.792238668e+00 | Ndiff  207.443
# BIRTH @ lap 30.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 30.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    30.000/100 after     29 sec. |    957.9 MiB | K   11 | loss  1.792136751e+00 | Ndiff  189.163
# BIRTH @ lap 31.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 31.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    31.000/100 after     29 sec. |    957.9 MiB | K   11 | loss  1.792075739e+00 | Ndiff  157.238
# BIRTH @ lap 32.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 32.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    32.000/100 after     30 sec. |    957.9 MiB | K   11 | loss  1.792042913e+00 | Ndiff  137.201
# BIRTH @ lap 33.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 33.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    33.000/100 after     31 sec. |    957.9 MiB | K   11 | loss  1.792021781e+00 | Ndiff  120.182
# BIRTH @ lap 34.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 34.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    34.000/100 after     32 sec. |    957.9 MiB | K   11 | loss  1.792005528e+00 | Ndiff  105.212
# BIRTH @ lap 35.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 35.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    35.000/100 after     32 sec. |    957.9 MiB | K   11 | loss  1.791991629e+00 | Ndiff   92.674
# BIRTH @ lap 36.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 36.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    36.000/100 after     33 sec. |    957.9 MiB | K   11 | loss  1.791979684e+00 | Ndiff   82.250
# BIRTH @ lap 37.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 37.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    37.000/100 after     34 sec. |    957.9 MiB | K   11 | loss  1.791969855e+00 | Ndiff   73.243
# BIRTH @ lap 38.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 38.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    38.000/100 after     35 sec. |    957.9 MiB | K   11 | loss  1.791961639e+00 | Ndiff   65.049
# BIRTH @ lap 39.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 39.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    39.000/100 after     35 sec. |    957.9 MiB | K   11 | loss  1.791954412e+00 | Ndiff   57.656
# BIRTH @ lap 40.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 40.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    40.000/100 after     36 sec. |    957.9 MiB | K   11 | loss  1.791947955e+00 | Ndiff   51.296
# BIRTH @ lap 41.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 41.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    41.000/100 after     37 sec. |    957.9 MiB | K   11 | loss  1.791941978e+00 | Ndiff   46.021
# BIRTH @ lap 42.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 42.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    42.000/100 after     38 sec. |    957.9 MiB | K   11 | loss  1.791936251e+00 | Ndiff   41.721
# BIRTH @ lap 43.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 43.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    43.000/100 after     38 sec. |    957.9 MiB | K   11 | loss  1.791930950e+00 | Ndiff   38.192
# BIRTH @ lap 44.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 44.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    44.000/100 after     39 sec. |    957.9 MiB | K   11 | loss  1.791926134e+00 | Ndiff   35.162
# BIRTH @ lap 45.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 45.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    45.000/100 after     39 sec. |    957.9 MiB | K   11 | loss  1.791921625e+00 | Ndiff   32.482
# BIRTH @ lap 46.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 46.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    46.000/100 after     40 sec. |    957.9 MiB | K   11 | loss  1.791917237e+00 | Ndiff   30.141
# BIRTH @ lap 47.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 47.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    47.000/100 after     41 sec. |    957.9 MiB | K   11 | loss  1.791912839e+00 | Ndiff   28.150
# BIRTH @ lap 48.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 48.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    48.000/100 after     41 sec. |    957.9 MiB | K   11 | loss  1.791908359e+00 | Ndiff   26.500
# BIRTH @ lap 49.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 49.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    49.000/100 after     42 sec. |    957.9 MiB | K   11 | loss  1.791903773e+00 | Ndiff   25.149
# BIRTH @ lap 50.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 50.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    50.000/100 after     43 sec. |    957.9 MiB | K   11 | loss  1.791899094e+00 | Ndiff   24.018
# BIRTH @ lap 51.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 51.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    51.000/100 after     43 sec. |    957.9 MiB | K   11 | loss  1.791894387e+00 | Ndiff   22.980
# BIRTH @ lap 52.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 52.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    52.000/100 after     44 sec. |    957.9 MiB | K   11 | loss  1.791889744e+00 | Ndiff   21.916
# BIRTH @ lap 53.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 53.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    53.000/100 after     44 sec. |    957.9 MiB | K   11 | loss  1.791885233e+00 | Ndiff   20.776
# BIRTH @ lap 54.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 54.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    54.000/100 after     45 sec. |    957.9 MiB | K   11 | loss  1.791880890e+00 | Ndiff   19.586
# BIRTH @ lap 55.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 55.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    55.000/100 after     46 sec. |    957.9 MiB | K   11 | loss  1.791876730e+00 | Ndiff   18.398
# BIRTH @ lap 56.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 56.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    56.000/100 after     46 sec. |    957.9 MiB | K   11 | loss  1.791872757e+00 | Ndiff   17.253
# BIRTH @ lap 57.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 57.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    57.000/100 after     47 sec. |    957.9 MiB | K   11 | loss  1.791868975e+00 | Ndiff   16.178
# BIRTH @ lap 58.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 58.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    58.000/100 after     48 sec. |    957.9 MiB | K   11 | loss  1.791865404e+00 | Ndiff   15.171
# BIRTH @ lap 59.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 59.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    59.000/100 after     48 sec. |    957.9 MiB | K   11 | loss  1.791862081e+00 | Ndiff   14.191
# BIRTH @ lap 60.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 60.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    60.000/100 after     49 sec. |    957.9 MiB | K   11 | loss  1.791859056e+00 | Ndiff   13.179
# BIRTH @ lap 61.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 61.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    61.000/100 after     49 sec. |    957.9 MiB | K   11 | loss  1.791856344e+00 | Ndiff   12.094
# BIRTH @ lap 62.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 62.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    62.000/100 after     50 sec. |    957.9 MiB | K   11 | loss  1.791853912e+00 | Ndiff   10.946
# BIRTH @ lap 63.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 63.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    63.000/100 after     51 sec. |    957.9 MiB | K   11 | loss  1.791851702e+00 | Ndiff    9.794
# BIRTH @ lap 64.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 64.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    64.000/100 after     51 sec. |    957.9 MiB | K   11 | loss  1.791849664e+00 | Ndiff    8.705
# BIRTH @ lap 65.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 65.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    65.000/100 after     52 sec. |    957.9 MiB | K   11 | loss  1.791847758e+00 | Ndiff    7.725
# BIRTH @ lap 66.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 66.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    66.000/100 after     53 sec. |    957.9 MiB | K   11 | loss  1.791845959e+00 | Ndiff    6.885
# BIRTH @ lap 67.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 67.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    67.000/100 after     53 sec. |    957.9 MiB | K   11 | loss  1.791844248e+00 | Ndiff    6.251
# BIRTH @ lap 68.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 68.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    68.000/100 after     54 sec. |    957.9 MiB | K   11 | loss  1.791842613e+00 | Ndiff    6.113
# BIRTH @ lap 69.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 69.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    69.000/100 after     54 sec. |    957.9 MiB | K   11 | loss  1.791841048e+00 | Ndiff    6.413
# BIRTH @ lap 70.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 70.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    70.000/100 after     55 sec. |    957.9 MiB | K   11 | loss  1.791839548e+00 | Ndiff    6.587
# BIRTH @ lap 71.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 71.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    71.000/100 after     56 sec. |    957.9 MiB | K   11 | loss  1.791838113e+00 | Ndiff    6.635
# BIRTH @ lap 72.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 72.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    72.000/100 after     56 sec. |    957.9 MiB | K   11 | loss  1.791836746e+00 | Ndiff    6.566
# BIRTH @ lap 73.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 73.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    73.000/100 after     57 sec. |    957.9 MiB | K   11 | loss  1.791835449e+00 | Ndiff    6.390
# BIRTH @ lap 74.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 74.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    74.000/100 after     57 sec. |    957.9 MiB | K   11 | loss  1.791834226e+00 | Ndiff    6.119
# BIRTH @ lap 75.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 75.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    75.000/100 after     58 sec. |    957.9 MiB | K   11 | loss  1.791833085e+00 | Ndiff    5.766
# BIRTH @ lap 76.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 76.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    76.000/100 after     59 sec. |    957.9 MiB | K   11 | loss  1.791832030e+00 | Ndiff    5.348
# BIRTH @ lap 77.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 77.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    77.000/100 after     59 sec. |    957.9 MiB | K   11 | loss  1.791831066e+00 | Ndiff    5.082
# BIRTH @ lap 78.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 78.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    78.000/100 after     60 sec. |    957.9 MiB | K   11 | loss  1.791830194e+00 | Ndiff    4.886
# BIRTH @ lap 79.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 79.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    79.000/100 after     60 sec. |    957.9 MiB | K   11 | loss  1.791829415e+00 | Ndiff    4.656
# BIRTH @ lap 80.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 80.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    80.000/100 after     61 sec. |    957.9 MiB | K   11 | loss  1.791828723e+00 | Ndiff    4.401
# BIRTH @ lap 81.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 81.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    81.000/100 after     62 sec. |    957.9 MiB | K   11 | loss  1.791828113e+00 | Ndiff    4.133
# BIRTH @ lap 82.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 82.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    82.000/100 after     62 sec. |    957.9 MiB | K   11 | loss  1.791827575e+00 | Ndiff    3.861
# BIRTH @ lap 83.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 83.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    83.000/100 after     63 sec. |    957.9 MiB | K   11 | loss  1.791827103e+00 | Ndiff    3.593
# BIRTH @ lap 84.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 84.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    84.000/100 after     64 sec. |    957.9 MiB | K   11 | loss  1.791826687e+00 | Ndiff    3.337
# BIRTH @ lap 85.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 85.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    85.000/100 after     64 sec. |    957.9 MiB | K   11 | loss  1.791826318e+00 | Ndiff    3.096
# BIRTH @ lap 86.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 86.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    86.000/100 after     65 sec. |    957.9 MiB | K   11 | loss  1.791825991e+00 | Ndiff    2.871
# BIRTH @ lap 87.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 87.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    87.000/100 after     66 sec. |    957.9 MiB | K   11 | loss  1.791825699e+00 | Ndiff    2.663
# BIRTH @ lap 88.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 88.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    88.000/100 after     66 sec. |    957.9 MiB | K   11 | loss  1.791825437e+00 | Ndiff    2.472
# BIRTH @ lap 89.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 89.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    89.000/100 after     67 sec. |    957.9 MiB | K   11 | loss  1.791825201e+00 | Ndiff    2.296
# BIRTH @ lap 90.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 90.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    90.000/100 after     67 sec. |    957.9 MiB | K   11 | loss  1.791824987e+00 | Ndiff    2.135
# BIRTH @ lap 91.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 91.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    91.000/100 after     68 sec. |    957.9 MiB | K   11 | loss  1.791824791e+00 | Ndiff    1.987
# BIRTH @ lap 92.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 92.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    92.000/100 after     69 sec. |    957.9 MiB | K   11 | loss  1.791824613e+00 | Ndiff    1.850
# BIRTH @ lap 93.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 93.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    93.000/100 after     69 sec. |    957.9 MiB | K   11 | loss  1.791824448e+00 | Ndiff    1.724
# BIRTH @ lap 94.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 94.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    94.000/100 after     70 sec. |    957.9 MiB | K   11 | loss  1.791824296e+00 | Ndiff    1.608
# BIRTH @ lap 95.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 95.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    95.000/100 after     71 sec. |    957.9 MiB | K   11 | loss  1.791824155e+00 | Ndiff    1.501
# BIRTH @ lap 96.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 96.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    96.000/100 after     71 sec. |    957.9 MiB | K   11 | loss  1.791824023e+00 | Ndiff    1.402
# BIRTH @ lap 97.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 97.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    97.000/100 after     72 sec. |    957.9 MiB | K   11 | loss  1.791823898e+00 | Ndiff    1.311
# BIRTH @ lap 98.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 98.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    98.000/100 after     73 sec. |    957.9 MiB | K   11 | loss  1.791823779e+00 | Ndiff    1.226
# BIRTH @ lap 99.000 : None attempted. 0 past failures. 0 too small. 11 too busy.
# MERGE @ lap 99.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#    99.000/100 after     74 sec. |    957.9 MiB | K   11 | loss  1.791823664e+00 | Ndiff    1.186
# BIRTH @ lap 100.00: Disabled. Beyond lap 100 (--b_stopLap).
# MERGE @ lap 100.00 : 0/55 accepted. Ndiff 0.00. 0 skipped.
#   100.000/100 after     74 sec. |    957.9 MiB | K   11 | loss  1.791823550e+00 | Ndiff    1.292
# ... done. not converged. max laps thru data exceeded.

# %%
test_preds =  []
train_preds = []

LP_test = model.calc_local_params(test_data_for_dpmm)
resp_test = LP_test['resp'] 
preds_eval = resp_test.argmax(axis=1)
test_preds = test_preds + preds_eval.tolist()
test_preds = np.array(test_preds)

LP_train = model.calc_local_params(train_data_for_dpmm)
resp_train = LP_train['resp'] 
preds_t = resp_train.argmax(axis=1)
train_preds = train_preds + preds_t.tolist()
train_preds = np.array(train_preds)


print('test accuracy: ', unsupervised_clustering_accuracy(test_label, test_preds)*100)
print('train accuracy: ', unsupervised_clustering_accuracy(train_label, train_preds)*100)
# Out:
# test accuracy:  48.3
# train accuracy:  58.6125
